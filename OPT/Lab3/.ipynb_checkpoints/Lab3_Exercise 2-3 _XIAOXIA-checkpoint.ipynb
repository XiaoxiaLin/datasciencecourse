# %% [markdown]
# # LAB3 - Newton method principles
#
# ## Exercise 2:

# %% [markdown]
# $$       f(x_1,x_2) = x^2_1 (4- 2.1x^2_1+\frac{1}{3}x^4_1)+x_1x_2+x^2_2(-4+4x^2_2)  $$

# %%
import numpy as np
from numpy.linalg import inv

X, Y = np.arange(-2, 2, 0.1),np.arange(-1.2, 1.2, 0.1)
X, Y = np.meshgrid(X, Y)
Z = np.multiply(X**2,(4-2.1* X**2 + (1./3)*X**4)) + np.multiply(X,Y)+ np.multiply((Y**2),(-4+4*Y**2))

# Compute gradient 

gradx, grady = 8*X-8.4*(X**3)+2*(X**5)+Y, X - 8*Y + 16*(Y**3)

# define functions

def f(X,Y):
    return (X**2)*(4-2.1* X**2 + (1./3)*X**4) + X*Y + (Y**2)*(-4+4*Y**2)

def df_X(X,Y): 
    return 8*X-8.4*(X**3)+2*(X**5)+Y

def df_Y(X,Y):
    return X-8*Y+16*(Y**3)

def df (X,Y):
    df = np.array([df_X(X,Y)], [df_Y(X,Y)])
    return df

def hessian (X,Y): 
    DD_XX = 8-25.2*X**2+10*X**4  
    DD_YY = 48*Y**2-8
    DD_XY, DD_YX = 1,1
    H = np.array([[DD_XX, DD_XY], [DD_YX, DD_YY]])
    return H

def det (H):
    return H[0][0]*H[1][1]-H[0][1]*H[1][0]

# %% [markdown]
# ### Surface plot 3D + contour plot

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
# %matplotlib inline

# Surface plot 3D + contour plot
fig = plt.figure(figsize=(20,10))
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,linewidth=0, antialiased=False)
ax.contour(X,Y,Z,30,zdir='z',offset=0)
plt.contour(X,Y,Z,100)

# %% [markdown]
# ## 2.1 Gradient descent method

# %%
# Contour plot en 2D
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.contour(X, Y, Z, 100)
plt.streamplot(X, Y, gradx, grady)

alpha = 1  # initial step
pt = [-0.8,-1]   # initial point
aux = pt[:]
listax, listay = [pt[0]], [pt[1]]   
iter = 0
step_reduction = 0

print "Initial point: %s" %pt
while alpha>10**(-5) and abs(f(pt[0]-alpha*df_X(pt[0],pt[1]),pt[1]-alpha*df_Y(pt[0],pt[1]))-f(pt[0],pt[1]))>10**(-5):  
    
    # backtracking algorithm to compute a good value for alpha
    df = [df_X(pt[0],pt[1]), df_Y(pt[0],pt[1])] 
    if f(pt[0]- alpha * df[0], pt[1]- alpha * df[1])> f(pt[0],pt[1]):
        alpha = alpha/2. 
        step_reduction +=1
    else:
        iter +=1
        plt.plot(pt[0],pt[1],'ro')
        #print "We have used the gradient descent at the point %s with step %s" %(pt, alpha)
        aux[0] += -alpha * df[0]
        aux[1] += -alpha * df[1]
        pt = aux[:]
        alpha = 1
        listax.append(pt[0])
        listay.append(pt[1])  
        
print "Step reductions: %s \nSteps by Gradient descent method:%s "  %(step_reduction, iter)
print "Total iterations to the minimum %s is:" %pt, iter+step_reduction
plt.plot(listax,listay,'k')
plt.show()
# Out:
# Initial point: [-0.8, -1]
# Step reductions: 20
# Steps by Gradient descent method:8
# Total iterations to the minimum [-0.09024589481797773, 0.7127945110163003] is: 28

# %% [markdown]
# ## 2.2 If the Hessian is positive definite, use the Newton method to perform the descent. Otherwise, use the gradient descent to perform the descent.
#
# If the Hessian is positive definite at x, then f attains a local minimum at x. If the Hessian is negative definite at x, then f attains a local maximum at x. If the Hessian has both positive and negative eigenvalues then x is a saddle point for f. Otherwise the test is inconclusive. This implies that, at a local minimum (respectively, a local maximum), the Hessian is positive-semi-definite (respectively, negative semi-definite).
#
# In two variables, the determinant can be used, because the determinant is the product of the eigenvalues. If it is positive then the eigenvalues are both positive, or both negative. If it is negative then the two eigenvalues have different signs. If it is zero, then the second derivative test is inconclusive.

# %%
# Contour plot en 2D
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.contour(X, Y, Z, 100)
plt.streamplot(X, Y, gradx, grady)

alpha = 1  # initial step
pt = [-0.8,-1]   # initial point
aux = pt[:]
listax, listay = [pt[0]], [pt[1]]   
iter = 0
step_reduction = 0
iter_newton = 0
iter_grad = 0

print "Initial point: %s" %pt
while alpha>10**(-5) and abs(f(pt[0]-alpha*df_X(pt[0],pt[1]),pt[1]-alpha*df_Y(pt[0],pt[1]))-f(pt[0],pt[1]))>10**(-5):  
    iter +=1
    df = [df_X(pt[0],pt[1]), df_Y(pt[0],pt[1])] 
    H = hessian(pt[0],pt[1])
    d = det(H)
    # If the Hessian is positive definite, use the Newton method to perform the descent. 
    if d>0 and H[0][0] > 0:  
        plt.plot(pt[0],pt[1],'go')
        invH = inv(H)
        direction = np.dot(invH,df)
        aux[0] = pt[0] -alpha * direction[0]
        aux[1] = pt[1] -alpha * direction[1]
        
        # backtracking algorithm to compute a good value for alpha
        if f(aux[0], aux[1])> f(pt[0],pt[1]):
            alpha = alpha/2.  
            step_reduction +=1
        else:
            pt=aux[:]
            iter_newton +=1
            alpha = 1

    # Otherwise, use the gradient descent to perform the descent.
    else:
        plt.plot(pt[0],pt[1],'ro')
        #print "We have used the gradient descent at the point %s with step %s" %(pt, alpha)
        aux[0] = pt[0] -alpha * df[0]
        aux[1] = pt[1] -alpha * df[1]
        
        if f(aux[0], aux[1])> f(pt[0],pt[1]):
            alpha = alpha/2.  
            step_reduction +=1 
        else:
            pt = aux[:]
            iter_grad +=1
            alpha = 1
    listax.append(pt[0])
    listay.append(pt[1])
            
print "Step reductions: %s \nSteps by Newton method: %s \nSteps by Gradient descent method:%s "  %(step_reduction, iter_newton, iter_grad) 
print "Total iterations to the minimum %s is %s" %(pt, step_reduction+iter_newton+iter_grad)
plt.plot(listax,listay,'k')
plt.show()
# Out:
# Initial point: [-0.8, -1]
# Step reductions: 7
# Steps by Newton method: 3
# Steps by Gradient descent method:3
# Total iterations to the minimum [-0.089842765351979201, 0.71266228090102457] is 13

# %% [markdown]
# ## Exercise 3: The Rosenbrock function

# %% [markdown]
# $$ f(x_1,x_2)=(a-x_1)^2+b(x_2-x_1^2)^2   $$

# %%
# %matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

# Rosenbrock function
a, b =1, 100
X = np.arange(-3, 3, 0.1)
Y = np.arange(-3, 3, 0.1)
X, Y = np.meshgrid(X, Y)
Z = (a-X)**2+b*(Y-(X**2))**2

# Compute gradient 
gradx = -2*a + 2*X-4*b*X*Y +4*b*X**3
grady = 2*b*Y - 2*b*X**2

# define functions
def df_X(X,Y):
    return -2 *(a-X)-4*b*(Y-X**2)*X

def df_Y(X,Y):
    return 2*b*Y - 2*b*X**2

def f(X,Y):
    return (a-X)**2+b*(Y-(X**2))**2

def hessian (X,Y): 
    DD_XX =  2-4*b*Y+12*b*X**2 
    DD_XY = -4*b*X
    DD_YY = 2*b
    DD_YX = -4*b*X
    H = np.array([[DD_XX, DD_XY], [DD_YX, DD_YY]])
    return H

def det (H):
    return H[0][0]*H[1][1]-H[0][1]*H[1][0]

# %% [markdown]
# ### Surface plot 3D + contour plot

# %%
fig = plt.figure(figsize=(20,15))
 
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,linewidth=0, antialiased=False)
ax.contour(X,Y,Z,30,zdir='z',offset=0)
plt.contour(X,Y,Z,100)

# %% [markdown]
# ## 3.1 Gradient descent method

# %%
# Contour plot en 2D
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.contour(X, Y, Z, 50)
plt.streamplot(X, Y, gradx, grady)

alpha = 1  # initial step
pt = [-1.5,-2]   # initial point
aux = pt[:]
listax, listay = [pt[0]], [pt[1]]   
iter = 0
step_reduction = 0

print "Initial point: %s" %pt
while alpha>10**(-5) and abs(f(pt[0]-alpha*df_X(pt[0],pt[1]),pt[1]-alpha*df_Y(pt[0],pt[1]))-f(pt[0],pt[1]))>10**(-15):  
    
    # backtracking algorithm to compute a good value for alpha
    df = [df_X(pt[0],pt[1]), df_Y(pt[0],pt[1])] 
    if f(pt[0]-alpha*df[0], pt[1]-alpha*df[1])> f(pt[0],pt[1]):
        alpha = alpha/2.  
        step_reduction +=1
        
    else:
        iter +=1
        plt.plot(pt[0],pt[1],'ro')
        aux[0] += -alpha * df[0]
        aux[1] += -alpha * df[1]
        pt=aux[:]
        alpha = 1

        listax.append(pt[0])
        listay.append(pt[1])
        
print "Step reductions: %s \nSteps by Gradient descent method:%s "  %(step_reduction, iter) 
print "Total iterations to the minimum %s using gradient descent is:" %pt, step_reduction+iter
plt.plot(listax,listay,'k')
plt.show()
# Out:
# Initial point: [-1.5, -2]
# Step reductions: 90825
# Steps by Gradient descent method:10147
# Total iterations to the minimum [0.9999921943616166, 0.9999843416169893] using gradient descent is: 100972

# %% [markdown]
# ## 3.2 Newton method

# %%
# Contour plot en 2D
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.contour(X, Y, Z, 100)
plt.streamplot(X, Y, gradx, grady)

alpha = 10  # initial step
pt = [-1.5,-2]   # initial point
aux = pt[:]
listax, listay = [pt[0]], [pt[1]]   

step_reduction = 0
iter_newton = 0
iter_grad = 0

""" 
while alpha>10**(-5) and abs(f(pt[0]-alpha*df_X(pt[0],pt[1]),pt[1]-alpha*df_Y(pt[0],pt[1]))-f(pt[0],pt[1]))>10**(-15):  
    
    # backtracking algorithm to compute a good value for alpha
    df = [df_X(pt[0],pt[1]), df_Y(pt[0],pt[1])] 
    if f(pt[0]-alpha*df[0], pt[1]-alpha*df[1])> f(pt[0],pt[1]):
        alpha = alpha/2.  
        step_reduction +=1
  
    else: 
        H = hessian(pt[0],pt[1])
        d = det(H)  
     
        # If the Hessian is positive definite, use the Newton method to perform the descent. 
        if d>0 and H[1][1] > 0:  
            iter_newton +=1
            plt.plot(pt[0],pt[1],'go')
            invH = inv(H)
            direction = np.dot(invH,df) 
            #direction = np.linalg.solve(H,df)
            pt[0] += -alpha * direction[0]
            pt[1] += -alpha * direction[1]
            listax.append(pt[0])
            listay.append(pt[1])
          
        # Otherwise, use the gradient descent to perform the descent.
        else:
            iter_grad +=1
            plt.plot(pt[0],pt[1],'ro')
            print "We have used the gradient descent at the point %s with step %s" %(pt, alpha)
            aux[0] += -alpha * df[0]
            aux[1] += -alpha * df[1]
            pt = aux [:]
            alpha = 1
            listax.append(pt[0])
            listay.append(pt[1])
""" 
print "Initial point: %s" %pt
while alpha>10**(-5) and abs(f(pt[0]-alpha*df_X(pt[0],pt[1]),pt[1]-alpha*df_Y(pt[0],pt[1]))-f(pt[0],pt[1]))>10**(-5):  
    iter +=1
    df = [df_X(pt[0],pt[1]), df_Y(pt[0],pt[1])] 
    H = hessian(pt[0],pt[1])
    d = det(H)
    # If the Hessian is positive definite, use the Newton method to perform the descent. 
    if d>0 and H[0][0] > 0:  
        plt.plot(pt[0],pt[1],'go')
        invH = inv(H)
        direction = np.dot(invH,df)
        aux[0] = pt[0] -alpha * direction[0]
        aux[1] = pt[1] -alpha * direction[1]
        
        # backtracking algorithm to compute a good value for alpha
        if f(aux[0], aux[1])> f(pt[0],pt[1]):
            alpha = alpha/2.  
            step_reduction +=1
        else:
            pt=aux[:]
            iter_newton +=1
            alpha = 1

    # Otherwise, use the gradient descent to perform the descent.
    else:
        plt.plot(pt[0],pt[1],'ro')
        #print "We have used the gradient descent at the point %s with step %s" %(pt, alpha)
        aux[0] = pt[0] -alpha * df[0]
        aux[1] = pt[1] -alpha * df[1]
        
        if f(aux[0], aux[1])> f(pt[0],pt[1]):
            alpha = alpha/2.  
            step_reduction +=1 
        else:
            pt = aux[:]
            iter_grad +=1
            alpha = 1
    listax.append(pt[0])
    listay.append(pt[1])


print "Step reductions: %s \nSteps by Newton method: %s \nSteps by Gradient descent method:%s "  %(step_reduction, iter_newton, iter_grad) 
print "Total iterations to the minimum %s is %s" %(pt, step_reduction+iter_newton+iter_grad)
plt.plot(listax,listay,'k')
plt.show()
# Out:
# Initial point: [-1.5, -2]
# Step reductions: 18
# Steps by Newton method: 23
# Steps by Gradient descent method:1
# Total iterations to the minimum [0.9999999990249292, 0.99999999804673134] is 42

# %% [markdown]
# ## NOTE:
# The Newton method requires, in general, less iterations than the gradient descent to arrive to the minimum. But the disadvantage of the Newton method is that it requires solving the linear system of equations $$ ∇^2f(x^k)d^k =−∇f(x^k)$$ and thus it requires higher computational effort. In addition, one needs to know if the Hessian matrix if positive definite in order to be sure that the vector $d^k$ is a descent direction. There are methods that tackle the previous computational issues, namely the conjugate gradient descent algorithm. In any case, take into account that the Newton method has great advantages over the gradient descent method. But this does not necessarily mean that the Newton method is always better than the gradient descent. In some cases the gradient descent may be good enough for the problem to be solved.

# %% [markdown]
# ## Final comments:
#
# <b>Exercise2</b>: the gradient descent(with backtracking) is good enough. For some initial points we even need less iterations using the gradient descent method than the Newton method.
#
# <b>Exercise3 (Rosenbrock function)</b>: The global minimum is inside a long, narrow, parabolic shaped valley. It requires a lot of iterations of the gradient descent in order to arrive to the minimum. This is due to the fact that during iterations the gradient descent continuously jumps from one side to the other side of the valley without taking into account the shape of the valley. It gets better when we combine Gradient descent method with the backtracking algorithm. However the result is still not as good as the Newton method.
#
# Let us compare the results. Taking the initial point (-1.5, -2),
#
#    <b>gradient descent method:</b>
#     - Step reductions: 90825
#     - Steps by Gradient descent method:10147
#     - Total iterations to the minimum [0.9999921943616166, 0.9999843416169893] is: 100972
#
#    <b>Newton method:</b>
#     - Step reductions: 14
#     - Steps by Newton method: 33587
#     - Steps by Gradient descent method:0
#     - Total iterations to the minimum [0.99999881786381151, 0.99999763293465327] is 33601
